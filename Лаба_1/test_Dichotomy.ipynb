# %%
from sympy import *
init_printing()
# %%matplotlib inline
# Out:
# UsageError: Line magic function `%%matplotlib` not found.

# %%
# Вариант 16
from dichotomy import DichotomysMethod
a = -5
b = 5
var('x y')
y = 0.93 * x ** 5 - 0.71 * x ** 4 -0.53 * x ** 3 + 2.1 * x ** 2 - 10.5
DichotomysMethod.plot(a, b, y, x)
solution = DichotomysMethod.dichotomy(a, b, y, x, E=1e-5)
print('\nНевязка решения:')
display(DichotomysMethod.residual(y, x, solution))
# Out:
# x1 = 0.0
# x2 = 2.5
# x3 = 1.25
# x4 = 1.875
# x5 = 1.5625
# x6 = 1.71875
# x7 = 1.640625
# x8 = 1.6796875
# x9 = 1.69921875
# x10 = 1.689453125
# x11 = 1.6943359375
# x12 = 1.69189453125
# x13 = 1.690673828125
# x14 = 1.6912841796875
# x15 = 1.69097900390625
# x16 = 1.691131591796875
# x17 = 1.6912078857421875
# x18 = 1.6911697387695312
# x19 = 1.6911506652832031
# x20 = 1.6911602020263672
# x21 = 1.6911649703979492
# x22 = 1.6911673545837402
# x23 = 1.6911661624908447
# x24 = 1.691165566444397
#
# Невязка решения:
# 2.57506140055597e-6

# %%
# Вариант 15
from dichotomy import DichotomysMethod
a = -100
b = 100
var('x y')
y = x ** 5 + 10.2 * x ** 4 -5.7 * x ** 3 -1.2 * x ** 2 + 8.6 * x - 21
DichotomysMethod.plot(a, b, y, x)
solution = DichotomysMethod.dichotomy(a, b, y, x, E=1e-3)
print('\nНевязка решения:')
display(DichotomysMethod.residual(y, x, solution))
# Out:
# x1 = 0.0
# x2 = 50.0
# x3 = 25.0
# x4 = 12.5
# x5 = 6.25
# x6 = 3.125
# x7 = 1.5625
# x8 = 0.78125
# x9 = 1.171875
# x10 = 1.3671875
# x11 = 1.26953125
# x12 = 1.220703125
# x13 = 1.1962890625
# x14 = 1.18408203125
# x15 = 1.177978515625
# x16 = 1.1749267578125
# x17 = 1.17645263671875
# x18 = 1.177215576171875
# x19 = 1.1768341064453125
# x20 = 1.1770248413085938
# x21 = 1.1769294738769531
# x22 = 1.1769771575927734
# x23 = 1.1770009994506836
#
# Невязка решения:
# 0.000538805711196133

# %%
# Вариант 11
from dichotomy import DichotomysMethod
a = -100
b = 100
var('x y')
y = x ** 5 -20.2 * x ** 4 + 132.18 * x ** 3 -60.592 * x ** 2 + -72.693 * x - 14.525
DichotomysMethod.plot(a, b, y, x)
solution = DichotomysMethod.dichotomy(a, b, y, x, E=1e-3)
print('\nНевязка решения:')
display(DichotomysMethod.residual(y, x, solution))
# Out:
# x1 = 0.0
# x2 = 50.0
# x3 = 25.0
# x4 = 12.5
# x5 = 6.25
# x6 = 3.125
# x7 = 1.5625
# x8 = 0.78125
# x9 = 1.171875
# x10 = 1.3671875
# x11 = 1.26953125
# x12 = 1.220703125
# x13 = 1.1962890625
# x14 = 1.20849609375
# x15 = 1.202392578125
# x16 = 1.1993408203125
# x17 = 1.20086669921875
# x18 = 1.200103759765625
# x19 = 1.1997222900390625
# x20 = 1.1999130249023438
# x21 = 1.2000083923339844
# x22 = 1.199960708618164
# x23 = 1.1999845504760742
# x24 = 1.1999964714050293
# x25 = 1.2000024318695068
#
# Невязка решения:
# -0.000562640918367663
